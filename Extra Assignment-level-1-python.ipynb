# %% [markdown]
# # print Statement
# output: HOPE AI

# %%
print("HOPE AI")

# %% [markdown]
# # Buy input
# output:Enter your institute name? : HOPE AI

# %%
name=input("Enter your institute name? :")
# Out:
# Enter your institute name? : HOPE AI

# %% [markdown]
# # Buy inputs
# output:
# Enter your name: Raj
# Enter your age: 15
# Enter your school name: Guru school
# Enter your drgree: B.E CSE

# %%
person_name=input("Enter your name:")
person_age=input("Enter your age:")
person_school=input("Enter your school name:")
person_degree=input("Enter your drgree:")
# Out:
# Enter your name: Raj
# Enter your age: 15
# Enter your school name: Guru school
# Enter your drgree: B.E CSE

# %% [markdown]
# # Addition
# Output
# a= 43
# b= 34
# add = 77

# %%
a=43
print("a=",a)
b=34
print("b=",b)
add = a+b
print("add =",add)
# Out:
# a= 43
# b= 34
# add = 77

# %% [markdown]
# # Subtraction
# a= 43
# b= 34
# Sub = 9

# %%
a=43
print("a=",a)
b=34
print("b=",b)
sub = a-b
print("sub =",sub)
# Out:
# a= 43
# b= 34
# sub = 9

# %% [markdown]
# # Multiplication
# a= 63
# b= 97
# Mul = 6111

# %%
a=63
print("a=",a)
b=97
print("b=",b)
mul = a*b
print("mul =",mul)
# Out:
# a= 63
# b= 97
# mul = 6111

# %% [markdown]
# # Division
# a= 76
# b= 31
# Float Div = 2.4516129032258065

# %%
a=76
print("a=",a)
b=31
print("b=",b)
float_div = a/b
print("float_div =",float_div)
# Out:
# a= 76
# b= 31
# float_div = 2.4516129032258065

# %% [markdown]
# # Floor division
# a= 76
# b= 31
# Floor Div = 2

# %%
a=76
print("a=",a)
b=31
print("b=",b)
print("Floor Div =",a // b)
# Out:
# a= 76
# b= 31
# Floor Div = 2

# %% [markdown]
# # Modulo
# a= 76
# b= 31
# Modulo = 14

# %%
a=76
print("a=",a)
b=31
print("b=",b)
Modulo = a%b
#print("Modulo =",a % b)
print("Modulo =", Modulo)
# Out:
# a= 76
# b= 31
# Modulo = 14

# %% [markdown]
# # Power (Calculate square root using power ** )
# a= 4
# b= 4
# Power = 256

# %%
a=4
print("a=",a)
b=4
print("b=",b)
Power = a**b
print("Power =", Power)
# Out:
# a= 4
# b= 4
# Power = 256
